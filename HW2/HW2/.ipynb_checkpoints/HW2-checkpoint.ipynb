# %%
import os,sys,re,csv
import pickle
from collections import Counter, defaultdict
import numpy as np
import scipy
import math
import random
import nltk
from scipy.spatial.distance import cosine
from nltk.corpus import stopwords
from numba import jit
nltk.download('punkt')
nltk.download('stopwords')
import nltk
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chenjieqing/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chenjieqing/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords = set(stopwords.words('english'))

# %%
random.seed(10)
np.random.seed(10)
randcounter = 10
np_randcounter = 10


vocab_size = 0
hidden_size = 100
uniqueWords = [""]                      #... list of all unique tokens
wordcodes = {}                          #... dictionary mapping of words to indices in uniqueWords
wordcounts = Counter()                  #... how many times each token occurs
samplingTable = []                      #... table to draw negative samples from

# %%
def loadData(filename):
    global uniqueWords, wordcodes, wordcounts
    override = False
    if override:
        #... for debugging purposes, reloading input file and tokenizing is quite slow
        #...  >> simply reload the completed objects. Instantaneous.
        fullrec = pickle.load(open("w2v_fullrec.p","rb"))
        wordcodes = pickle.load( open("w2v_wordcodes.p","rb"))
        uniqueWords= pickle.load(open("w2v_uniqueWords.p","rb"))
        wordcounts = pickle.load(open("w2v_wordcounts.p","rb"))
        return fullrec


    # ... load in first 15,000 rows of unlabeled data file.  You can load in
    # more if you want later (and should do this for the final homework)
    handle = open(filename, "r", encoding="utf8")
    fullconts = handle.read().split("\n")
#     fullconts = fullconts[1:15000]  # (TASK) Use all the data for the final submission
    #... apply simple tokenization (whitespace and lowercase)
    fullconts = [" ".join(fullconts).lower()]
#     print(fullconts)





    print ("Generating token stream...")
    #... (TASK) populate fullrec as one-dimension array of all tokens in the order they appear.
    #... ignore stopwords in this process
    #... for simplicity, you may use nltk.word_tokenize() to split fullconts.
    #... keep track of the frequency counts of tokens in origcounts.
    fullrec = nltk.word_tokenize(fullconts[0])
#     print(fullrec)
    min_count = 50
    origcounts = Counter(fullrec)
#     print(origcounts)





    print ("Performing minimum thresholding..")
#     #... (TASK) populate array fullrec_filtered to include terms as-is that appeared at least min_count times
#     #... replace other terms with <UNK> token.
#     #... update frequency count of each token in dict wordcounts where: wordcounts[token] = freq(token)



#     #... after filling in fullrec_filtered, replace the original fullrec with this one.
    fullrec_filtered = ['<UNK>' if origcounts[word] < min_count else word for word in fullrec]
    fullrec_filtered2 = []
    for word in fullrec_filtered:
        if word not in stopwords:
            fullrec_filtered2.append(word)
#     print(fullrec_filtered)
    fullrec = fullrec_filtered2
    wordcounts = Counter(fullrec)





    print ("Producing one-hot indicies")
#     #... (TASK) sort the unique tokens into array uniqueWords
#     #... produce their one-hot indices in dict wordcodes where wordcodes[token] = onehot_index(token)
#     #... replace all word tokens in fullrec with their corresponding one-hot indices.
    uniqueWords = sorted([word for word in wordcounts])#... fill in
    
#     print(uniqueWords)
    wordcodes = {}
    for word in uniqueWords:
#         one_hot = np.zeros(len(uniqueWords),)
#         wordIndex = uniqueWords.index(word)
#         one_hot[wordIndex] = 1
#         wordcodes[word] = one_hot
        wordcodes[word] = uniqueWords.index(word)
#     print(wordcodes)
#     wordcodes = #... fill in

    




#     #... close input file handle
    handle.close()

    fullrec  = [wordcodes[word] for word in fullrec]

#     #... store these objects for later.
#     #... for debugging, don't keep re-tokenizing same data in same way.
#     #... just reload the already-processed input data with pickles.
#     #... NOTE: you have to reload data from scratch if you change the min_count, tokenization or number of input rows

    pickle.dump(fullrec, open("w2v_fullrec.p","wb+"))
    pickle.dump(wordcodes, open("w2v_wordcodes.p","wb+"))
    pickle.dump(uniqueWords, open("w2v_uniqueWords.p","wb+"))
    pickle.dump(dict(wordcounts), open("w2v_wordcounts.p","wb+"))


#     #... output fullrec should be sequence of tokens, each represented as their one-hot index from wordcodes.
#     print(fullrec)
    return fullrec

# %%
@jit
def sigmoid(x):
    return 1.0/(1+np.exp(-x))

# %%
def negativeSampleTable(train_data, uniqueWords, wordcounts, exp_power=0.75):
#     global wordcounts
    #... stores the normalizing denominator (count of all tokens, each count raised to exp_power)
    max_exp_count = 0
    table_size = 1e7
#     print(train_data)
    print ("Generating exponentiated count vectors")
    #... (TASK) for each uniqueWord, compute the frequency of that word to the power of exp_power
    #... store results in exp_count_array.
    exp_count_array = []
    for word in uniqueWords:
        if word != "<UNK>":
            exp_count_array.append(wordcounts[word]**exp_power) #... fill in
#     print(exp_count_array)
    max_exp_count = sum(exp_count_array)
    

    print ("Generating distribution")

    #... (TASK) compute the normalized probabilities of each term.
    #... using exp_count_array, normalize each value by the total value max_exp_count so that
    #... they all add up to 1. Store this corresponding array in prob_dist
    prob_dist = [count_freq / max_exp_count for count_freq in exp_count_array] #... fill in
#     print(prob_dist)




    print ("Filling up sampling table")
    #... (TASK) create a dict of size table_size where each key is a sequential number and its value is a one-hot index
    #... the number of sequential keys containing the same one-hot index should be proportional to its prob_dist value
    #... multiplied by table_size. This table should be stored in cumulative_dict.
    #... we do this for much faster lookup later on when sampling from this table.
    table_size = 1e7
    cumulative_dict = {}#... fill in
    
#     freqTempList = [freq*table_size for freq in prob_dist] 
# #     keyTempList = [i for i in range(table_size)]
#     valueTempList = []
#     for i,freq in freqTempList:
#         for j in freq:
#             valueTempList.append(train_data[i])
    begin = 0
    for i,prob in enumerate(prob_dist):
        freq = int(round(prob*table_size))
        for j in range(freq):
            cumulative_dict[j+begin] = i
        begin += freq
    
        
#     cumulative_dict = dict(zip(keyTempList,valueTempList))
            
            
        
    




    return cumulative_dict

# %%
def generateSamples(context_idx, num_samples):
    global samplingTable, uniqueWords, randcounter
    results = []
    #... (TASK) randomly sample num_samples token indices from samplingTable.
    #... don't allow the chosen token to be context_idx.
    #... append the chosen indices to results
    while len(results) < num_samples:
        sample = samplingTable[random.randint(0, len(samplingTable)-1)]
#         while samplingTable[random.randint(0, len(samplingTable)-1)] = context_idx:
#             sample = samplingTable[random.randint(0, len(samplingTable)-1)]
#         results.append(sample)
        if sample != context_idx:
            results.append(sample)


    return results

# %%
@jit(nopython=True)
def performDescent(learning_rate, center_token, context_index,W1,W2,negative_indices):# delete the sequence_chars and num_samples
    # sequence chars was generated from the mapped sequence in the core code
    nll_new = 0
#     for k in range(0, len(sequence_chars)):
        #... (TASK) implement gradient descent. Find the current context token from sequence_chars
        #... and the associated negative samples from negative_indices. Run gradient descent on both
        #... weight matrices W1 and W2.
        #... compute the total negative log-likelihood and store this in nll_new.
    
    H = W1[center_token].T
    y_predict = sigmoid((W2[:,context_index].T.dot(H)))
    error = y_predict - 1
    
    total = error*W2[:,context_index]
    W2[:,context_index] = W2[:,context_index] - learning_rate*error*H
    nll_new += -np.log(sigmoid((W2[:,context_index].T.dot(H))))
    
    for index in negative_indices:
        y_predict_negative = sigmoid((W2[:,index].T.dot(H)))
        error_negative = y_predict_negative - 0
        
        total += error_negative*W2[:,index]
        W2[:,index] = W2[:,index] - learning_rate*error_negative*H 
        
        nll_new += -np.log(sigmoid((-W2[:,index].T.dot(H))))
        
    W1[center_token] = W1[center_token] - learning_rate*total.T
    

    

    



    return nll_new

# %%
def trainer(curW1 = None, curW2= None):
    global uniqueWords, wordcodes, fullsequence, vocab_size, hidden_size,np_randcounter, randcounter
    vocab_size = len(uniqueWords)           #... unique characters
    hidden_size = 100                       #... number of hidden neurons
    context_window = [-2,-1,1,2]            #... specifies which context indices are output. Indices relative to target word. Don't include index 0 itself.
    nll_results = []                        #... keep array of negative log-likelihood after every 1000 iterations


    #... determine how much of the full sequence we can use while still accommodating the context window
    start_point = int(math.fabs(min(context_window)))
    end_point = len(fullsequence)-(max(max(context_window),0))
    mapped_sequence = fullsequence



    #... initialize the weight matrices. W1 is from input->hidden and W2 is from hidden->output.
    if curW1==None:
        np_randcounter += 1
        W1 = np.random.uniform(-.5, .5, size=(vocab_size, hidden_size))
        W2 = np.random.uniform(-.5, .5, size=(hidden_size, vocab_size))
    else:
#         ... initialized from pre-loaded file
        W1 = curW1
        W2 = curW2



    #... set the training parameters
    epochs = 5
    num_samples = 4
    learning_rate = 0.05
    nll = 0
    iternum = 0
    


    indexUNK = wordcodes['<UNK>']
    #... Begin actual training
    for j in range(0,epochs):
        print ("Epoch: ", j)
        prevmark = 0

        #... For each epoch, redo the whole sequence...
        for i in range(start_point,end_point):
            iternum += 1

            if (float(i)/len(mapped_sequence))>=(prevmark+0.1):
                print ("Progress: ", round(prevmark+0.1,1))
                prevmark += 0.1
            if iternum%10000==0:
                print ("Negative likelihood: ", nll)
                nll_results.append(nll)
                nll = 0


            #... (TASK) determine which token is our current input. Remember that we're looping through mapped_sequence
            if mapped_sequence[i] != indexUNK :
                center_token = mapped_sequence[i]
#                 print(mapped_sequence[:10])
#                 print(center_token)#... fill in
            #... (TASK) don't allow the center_token to be <UNK>. move to next iteration if you found <UNK>.
            else:
                continue


#             iternum += 1
            #... now propagate to each of the context outputs
            for k in range(0, len(context_window)):

                #... (TASK) Use context_window to find one-hot index of the current context token.
                context_index = mapped_sequence[context_window[k] + i]#... fill in



                #... construct some negative samples
                negative_indices = generateSamples(context_index, num_samples)

                #... (TASK) You have your context token and your negative samples.
                #... Perform gradient descent on both weight matrices.
                #... Also keep track of the negative log-likelihood in variable nll.
                nll = performDescent(learning_rate, center_token, context_index,W1,W2,negative_indices)
                
                
                
                




    for nll_res in nll_results:
        print (nll_res)
    return [W1,W2]

# %%
def load_model():
    handle = open("saved_W1.data","rb")
    W1 = np.load(handle)
    handle.close()
    handle = open("saved_W2.data","rb")
    W2 = np.load(handle)
    handle.close()
    return [W1,W2]

# %%
#.................................................................................
#... Save the current results to an output file. Useful when computation is taking a long time.
#.................................................................................

def save_model(W1,W2):
    handle = open("saved_W1.data","wb+")
    np.save(handle, W1, allow_pickle=False)
    handle.close()

    handle = open("saved_W2.data","wb+")
    np.save(handle, W2, allow_pickle=False)
    handle.close()

# %%
word_embeddings = []
proj_embeddings = []
def train_vectors(preload=False):
    global word_embeddings, proj_embeddings
    if preload:
        [curW1, curW2] = load_model()
    else:
        curW1 = None
        curW2 = None
    [word_embeddings, proj_embeddings] = trainer(curW1,curW2)
    save_model(word_embeddings, proj_embeddings)

# %%
filename = 'unlabeled-data.txt'
#... load in the file, tokenize it and assign each token an index.
#... the full sequence of characters is encoded in terms of their one-hot positions

fullsequence= loadData(filename)
print ("Full sequence loaded...")
#print(uniqueWords)
#print (len(uniqueWords))



#... now generate the negative sampling table
print ("Total unique words: ", len(uniqueWords))
print("Preparing negative sampling table")
samplingTable = negativeSampleTable(fullsequence, uniqueWords, wordcounts)


#... we've got the word indices and the sampling table. Begin the training.
#... NOTE: If you have already trained a model earlier, preload the results (set preload=True) (This would save you a lot of unnecessary time)
#... If you just want to load an earlier model and NOT perform further training, comment out the train_vectors() line
#... ... and uncomment the load_model() line

train_vectors(preload= False)
[word_embeddings, proj_embeddings] = load_model()
# Out:
# Generating token stream...
# Performing minimum thresholding..
# Producing one-hot indicies
# Full sequence loaded...
# Total unique words:  14127
# Preparing negative sampling table
# Generating exponentiated count vectors
# Generating distribution
# Filling up sampling table
# Epoch:  0
# Negative likelihood:  2.4056919092394944
# Negative likelihood:  3.40898120333389
# Negative likelihood:  0.3935454328344853
# Negative likelihood:  1.7758130157689611
# Negative likelihood:  2.387889426172378
# Negative likelihood:  0.4505810670400268
# Negative likelihood:  2.14279326719098
# Negative likelihood:  1.1125817044054838
# Negative likelihood:  0.23848947612496027
# Negative likelihood:  2.5878634988202345
# Negative likelihood:  0.9689957844748285
# Negative likelihood:  1.2243425925101266
# Negative likelihood:  1.9096912111665685
# Negative likelihood:  0.26183049404755987
# Negative likelihood:  0.7757376505125599
# Negative likelihood:  3.560690963602234
# Negative likelihood:  0.1959696980435497
# Negative likelihood:  1.1568484458806167
# Negative likelihood:  1.6419207055999576
# Negative likelihood:  0.3439349475949425
# Negative likelihood:  0.6917618500935729
# Negative likelihood:  1.0231185906656592
# Negative likelihood:  0.5281686575058073
# Negative likelihood:  0.09365459859563814
# Negative likelihood:  0.2551857866112494
# Negative likelihood:  1.0591168924483454
# Negative likelihood:  1.8981306146951162
# Negative likelihood:  0.601487706290758
# Negative likelihood:  0.3108230981094501
# Negative likelihood:  3.4684047205566224
# Negative likelihood:  0.4234189510637494
# Negative likelihood:  1.8214805245506243
# Negative likelihood:  0.06459420444575507
# Negative likelihood:  0.6186397542604274
# Negative likelihood:  1.338560580441095
# Negative likelihood:  2.0141279911076744
# Negative likelihood:  1.8957450111728795
# Negative likelihood:  1.693489026965398
# Negative likelihood:  1.491255966602937
# Negative likelihood:  0.469533434728825
# Negative likelihood:  2.1889735115533955
# Negative likelihood:  1.7006801549708757
# Negative likelihood:  0.028834672566300155
# Negative likelihood:  1.1697738525546806
# Negative likelihood:  0.908336281569013
# Negative likelihood:  3.7116106906979636
# Negative likelihood:  1.1451231627995444
# Negative likelihood:  0.1741553387581909
# Negative likelihood:  0.8053429587435714
# Negative likelihood:  1.5869772255175025
# Negative likelihood:  0.16870017723746086
# Negative likelihood:  3.3190386490128714
# Negative likelihood:  1.3703652451714892
# Negative likelihood:  1.104950088212251
# Negative likelihood:  0.4962796700976003
# Negative likelihood:  2.7846686473048856
# Negative likelihood:  1.2649478323558712
# Negative likelihood:  1.0666002077420231
# Negative likelihood:  1.0475743093092376
# Negative likelihood:  1.3902619338170676
# Negative likelihood:  2.0660796416480514
# Negative likelihood:  1.709404297997645
# Negative likelihood:  0.34438165036748214
# Negative likelihood:  0.5419761288148216
# Negative likelihood:  1.8727986952576703
# Negative likelihood:  0.09325805972020312
# Negative likelihood:  0.37622106808279976
# Negative likelihood:  1.0606289150374133
# Negative likelihood:  2.072019948223172
# Negative likelihood:  1.6345867068745965
# Negative likelihood:  2.794667872506741
# Negative likelihood:  1.1170204735552576
# Negative likelihood:  0.6965214615319754
# Negative likelihood:  2.2777279497427263
# Negative likelihood:  0.5805737055353771
# Negative likelihood:  0.6312270898682212
# Negative likelihood:  1.0309342923779785
# Negative likelihood:  0.2660648875987951
# Negative likelihood:  0.8319448183428653
# Negative likelihood:  0.22826856745762217
# Negative likelihood:  3.1145407445499274
# Negative likelihood:  1.6840044205586602
# Negative likelihood:  3.3923163933768037
# Negative likelihood:  0.09157270368585048
# Negative likelihood:  2.08473366526786
# Negative likelihood:  0.7236720021804192
# Negative likelihood:  1.212965579209242
# Negative likelihood:  0.13574208605048416
# Negative likelihood:  1.7104284633852445
# Negative likelihood:  1.0524373955718653
# Negative likelihood:  3.5944435132295625
# Negative likelihood:  0.5549951138648518
# Negative likelihood:  0.04502674681051702
# Negative likelihood:  1.3618670304580294
# Negative likelihood:  0.7101952733148132
# Negative likelihood:  0.16262915721893845
# Negative likelihood:  1.555714594057766
# Negative likelihood:  0.47037648936188486
# Negative likelihood:  0.4360465827392084
# Negative likelihood:  0.8879633399516862
# Negative likelihood:  1.1702269297656602
# Negative likelihood:  2.788642434396883
# Negative likelihood:  2.113251406566798
# Negative likelihood:  0.38502575377422005
# Negative likelihood:  2.5975622676525734
# Negative likelihood:  2.9602261067779296
# Negative likelihood:  2.917283680212708
# Negative likelihood:  0.33396612316728164
# Negative likelihood:  0.3573535078842494
# Negative likelihood:  3.271791210023251
# Negative likelihood:  0.25507023783715255
# Negative likelihood:  1.621701895229694
# Negative likelihood:  5.452037125369938
# Progress:  0.1
# Negative likelihood:  1.4212232966506135
# Negative likelihood:  1.7055620273023246
# Negative likelihood:  0.8315316354650498
# Negative likelihood:  0.3183979890752079
# Negative likelihood:  1.9095930044924292
# Negative likelihood:  0.6267883370992795
# Negative likelihood:  0.6607278058150435
# Negative likelihood:  0.406636613676024
# Negative likelihood:  0.7262232545572102
# Negative likelihood:  0.7670222736787058
# Negative likelihood:  0.8688413165761669
# Negative likelihood:  2.4233942839763585
# Negative likelihood:  0.12869397323831708
# Negative likelihood:  1.0976315636477634
# Negative likelihood:  0.45452538630749006
# Negative likelihood:  1.3570026162607984
# Negative likelihood:  0.11568351443853521
# Negative likelihood:  0.0260932975069943
# Negative likelihood:  0.25044468827474764
# Negative likelihood:  3.294915427529091
# Negative likelihood:  1.2027369068723577
# Negative likelihood:  2.0307165315626357
# Negative likelihood:  0.853854647790318
# Negative likelihood:  0.15971306186071924
# Negative likelihood:  1.0674542007507828
# Negative likelihood:  0.6394817382578255
# Negative likelihood:  0.31981412192861153
# Negative likelihood:  2.3548673401429294
# Negative likelihood:  1.0633611123947926
# Negative likelihood:  0.9907969446704317
# Negative likelihood:  0.6926727209512422
# Negative likelihood:  0.918672266292885
# Negative likelihood:  1.6186854377891058
# Negative likelihood:  1.8007462889857038
# Negative likelihood:  1.0299984559535467
# Negative likelihood:  2.2450326154979745
# Negative likelihood:  0.053529107473752016
# Negative likelihood:  0.9392766395582013
# Negative likelihood:  0.3563179184532729
# Negative likelihood:  0.41881634067187073
# Negative likelihood:  0.217650619440038
# Negative likelihood:  1.3421662873045297
# Negative likelihood:  1.3839222541228504
# Negative likelihood:  0.5033381931258705
# Negative likelihood:  0.3549522904156089
# Negative likelihood:  2.263181507201497
# Negative likelihood:  1.4934699123909103
# Negative likelihood:  0.17194917193656456
# Negative likelihood:  3.9437253121906366
# Negative likelihood:  0.5456204318238329
# Negative likelihood:  0.24839595166528255
# Negative likelihood:  2.048584298631451
# Negative likelihood:  0.4029146554479568
# Negative likelihood:  0.32622160186873306
# Negative likelihood:  1.5783646401809897
# Negative likelihood:  0.23205600594250667
# Negative likelihood:  0.8766166152791772
# Negative likelihood:  0.935782535029257
# Negative likelihood:  0.9005839419484986
# Negative likelihood:  0.840382325867793
# Negative likelihood:  1.709571233411119
# Negative likelihood:  1.5265876779304568
# Negative likelihood:  0.2917892167042465
# Negative likelihood:  0.40029508390698354
# Negative likelihood:  0.4316689831701344
# Negative likelihood:  0.474260201498635
# Negative likelihood:  0.6796993160085302
# Negative likelihood:  2.0687491860640552
# Negative likelihood:  1.6412716863007646
# Negative likelihood:  0.7380209387461255
# Negative likelihood:  0.377725398053793
# Negative likelihood:  1.577063131352235
# Negative likelihood:  4.122443027127217
# Negative likelihood:  4.634564088306007
# Negative likelihood:  0.9803503041971727
# Negative likelihood:  0.9054537807638054
# Negative likelihood:  0.21560557421975035
# Negative likelihood:  0.5523356783252996
# Negative likelihood:  0.04408946783728717
# Negative likelihood:  0.031392291633476926
# Negative likelihood:  3.794525887047573
# Negative likelihood:  1.940164385724925
# Negative likelihood:  0.4887994085317809
# Negative likelihood:  3.9659290694292904
# Negative likelihood:  1.9147334592920018
# Negative likelihood:  2.70955101543968
# Negative likelihood:  0.9965456661592127
# Negative likelihood:  0.7471732359021556
# Negative likelihood:  0.08488410602020613
# Negative likelihood:  0.8920136238561451
# Negative likelihood:  1.4020809187009262
# Negative likelihood:  2.005331636353433
# Negative likelihood:  2.5654280895520407
# Negative likelihood:  0.5071134122791524
# Negative likelihood:  0.013611359162265024
# Negative likelihood:  0.8245518396366998
# Negative likelihood:  1.0715264903521033
# Negative likelihood:  0.177013983091397
# Negative likelihood:  0.6576357489763559
# Negative likelihood:  0.7294516686558002
# Negative likelihood:  0.43958354137634176
# Negative likelihood:  1.5557676630176458
# Negative likelihood:  2.7377571299612264
# Negative likelihood:  1.537695393311101
# Negative likelihood:  0.4555735590969975
# Negative likelihood:  0.4106560244079592
# Negative likelihood:  0.785595257252836
# Negative likelihood:  0.5586332995985219
# Negative likelihood:  0.16984461373264498
# Negative likelihood:  5.805521041712161
# Negative likelihood:  0.48094386622826185
# Negative likelihood:  0.6418229964260169
# Negative likelihood:  1.5403624352336824
# Negative likelihood:  0.21355640403723464
# Progress:  0.2
# Negative likelihood:  1.1716797694381824
# Negative likelihood:  2.1958962532929878
# Negative likelihood:  0.13831343742368965
# Negative likelihood:  0.7042535025882709
# Negative likelihood:  0.12195492796074321
# Negative likelihood:  0.47925338723637395
# Negative likelihood:  1.1868306652718013
# Negative likelihood:  1.7121711135148716
# Negative likelihood:  1.210492764399603
# Negative likelihood:  0.4450989933141944
# Negative likelihood:  0.9176660638024033
# Negative likelihood:  2.4037933991563705
# Negative likelihood:  3.054225046454341
# Negative likelihood:  0.5909946191850379
# Negative likelihood:  0.18941186739184798
# Negative likelihood:  2.371512490918671
# Negative likelihood:  0.21088768759842164
# Negative likelihood:  1.112254302014387
# Negative likelihood:  0.3898933947795297
# Negative likelihood:  0.8675696876441044
# Negative likelihood:  2.411806562495446
# Negative likelihood:  0.20039981661859227
# Negative likelihood:  5.043465548197913
# Negative likelihood:  1.5589949733790482
# Negative likelihood:  1.2810388877932206
# Negative likelihood:  2.0674312612714263
# Negative likelihood:  0.2471425801765236
# Negative likelihood:  1.5785471032459462
# Negative likelihood:  0.03817674751915018
# Negative likelihood:  2.3785330246608596
# Negative likelihood:  0.2463516050852551
# Negative likelihood:  2.9526009230588515
# Negative likelihood:  1.4984479887635793
# Negative likelihood:  0.2618436103505672
# Negative likelihood:  0.0018330478780550978
# Negative likelihood:  0.49468788707381356
# Negative likelihood:  0.8451098670716194
# Negative likelihood:  2.7676868580191374
# Negative likelihood:  3.7484278712858643
# Negative likelihood:  0.699374457223872
# Negative likelihood:  0.4862147942034366
# Negative likelihood:  0.8429641524897755
# Negative likelihood:  0.07823070878820004
# Negative likelihood:  0.5118339689364566
# Negative likelihood:  0.19717719972051498
# Negative likelihood:  0.7944831662091834
# Negative likelihood:  1.1341875106042818
# Negative likelihood:  1.1310836803235267
# Negative likelihood:  1.6700572426433233
# Negative likelihood:  1.7798075354023002
# Negative likelihood:  0.10032744637368053
# Negative likelihood:  0.4854652102247633
# Negative likelihood:  4.951300409680539
# Negative likelihood:  1.7362615948217863
# Negative likelihood:  1.2731727895311233
# Negative likelihood:  0.13002539450644224
# Negative likelihood:  0.46409396078542264
# Negative likelihood:  2.0427660095142697
# Negative likelihood:  3.229627037606349
# Negative likelihood:  0.9618389908059101
# Negative likelihood:  0.9128574543161331
# Negative likelihood:  0.12650058864352315
# Negative likelihood:  1.9096051036692108
# Negative likelihood:  1.0093283952703314
# Negative likelihood:  0.9749643302044027
# Negative likelihood:  3.9520071137828645
# Negative likelihood:  0.10569267991785775
# Negative likelihood:  0.07329283581422891
# Negative likelihood:  2.164607120211033
# Negative likelihood:  0.9537475713390934
# Negative likelihood:  0.6242922657916598
# Negative likelihood:  1.0218191348224972
# Negative likelihood:  0.1555308593657332
# Negative likelihood:  3.708942955928428
# Negative likelihood:  1.3061214699793844
# Negative likelihood:  0.8157549934603208
# Negative likelihood:  0.22454550775450285
# Negative likelihood:  0.2881259359443215
# Negative likelihood:  0.9778266177480411
# Negative likelihood:  0.486334634736476
# Negative likelihood:  1.4995214250187066
# Negative likelihood:  0.5753359986254512
# Negative likelihood:  2.2400047605833757
# Negative likelihood:  0.43343606526496314
# Negative likelihood:  0.018665499969493904
# Negative likelihood:  0.013472237639788082
# Negative likelihood:  0.0023505765962227665
# Negative likelihood:  0.5142051649867364
# Negative likelihood:  0.05121584516302657
# Negative likelihood:  0.8807498472009174
# Negative likelihood:  0.008990032121620714
# Negative likelihood:  0.009013416351913349
# Negative likelihood:  0.16381802706802273
# Negative likelihood:  0.0075311774286887095
# Negative likelihood:  0.06609122318507753
# Negative likelihood:  1.432467267337003
# Negative likelihood:  0.023409708314920938
# Negative likelihood:  0.03614876495455748
# Negative likelihood:  2.4388466285334136
# Negative likelihood:  0.2879478809819635
# Negative likelihood:  0.30687989401700333
# Negative likelihood:  0.01833757394567893
# Negative likelihood:  1.6850301956756015
# Negative likelihood:  1.6079299451701061
# Negative likelihood:  0.7525927583556008
# Negative likelihood:  0.1609355321593041
# Negative likelihood:  0.016465262859785022
# Negative likelihood:  0.21299772821064988
# Negative likelihood:  0.3000385461465009
# Negative likelihood:  0.798233995685002
# Negative likelihood:  1.4227708631272489
# Negative likelihood:  1.8170161417491257
# Negative likelihood:  1.4914634130776994
# Negative likelihood:  1.9622610407632324
# Progress:  0.3
# Negative likelihood:  2.713442115898359
# Negative likelihood:  0.9125445175731011
# Negative likelihood:  1.3034676768163933
# Negative likelihood:  2.5396606002349285
# Negative likelihood:  1.2885548783665495
# Negative likelihood:  0.22808395064985681
# Negative likelihood:  0.5462435826796066
# Negative likelihood:  0.8503974976552138
# Negative likelihood:  1.3764302412353497
# Negative likelihood:  0.04899670877958247
# Negative likelihood:  0.2264492761049388
# Negative likelihood:  0.9509469125379733
# Negative likelihood:  3.6179945291357485
# Negative likelihood:  0.7475429649540215
# Negative likelihood:  0.06375748611595941
# Negative likelihood:  0.13977933337079007
# Negative likelihood:  0.2855638980870089
# Negative likelihood:  0.9278054980324456
# Negative likelihood:  0.13168173576681003
# Negative likelihood:  1.153829027237298
# Negative likelihood:  0.85105027677887
# Negative likelihood:  0.01769538173240154
# Negative likelihood:  1.4131094910939002
# Negative likelihood:  0.2848205673289725
# Negative likelihood:  0.852627799584049
# Negative likelihood:  0.14501147414533924
# Negative likelihood:  0.861308398607626
# Negative likelihood:  0.3800592399821738
# Negative likelihood:  0.8729078205073006
# Negative likelihood:  0.3468565209099964
# Negative likelihood:  0.1507520970921529
# Negative likelihood:  0.5649152563495856
# Negative likelihood:  0.6949503392396423
# Negative likelihood:  0.03427163356040605
# Negative likelihood:  0.253803321669215
# Negative likelihood:  0.07000076779378421
# Negative likelihood:  0.18169337587787415
# Negative likelihood:  0.9433531675762091
# Negative likelihood:  0.052033006762576
# Negative likelihood:  1.0813986354411718
# Negative likelihood:  1.303660540163385
# Negative likelihood:  0.1340007860983804
# Negative likelihood:  3.1680664146719764
# Negative likelihood:  0.288368722530624
# Negative likelihood:  0.24049030138888358
# Negative likelihood:  0.4274364620003414
# Negative likelihood:  0.667281081109903
# Negative likelihood:  0.6524983532359651
# Negative likelihood:  0.08293554477768122
# Negative likelihood:  0.1341356645927388
# Negative likelihood:  2.6173605788428227
# Negative likelihood:  1.1827016368843224
# Negative likelihood:  1.7102038795646437
# Negative likelihood:  0.7646687295499577
# Negative likelihood:  0.19070250196693844
# Negative likelihood:  0.5470830467360104
# Negative likelihood:  2.0172072476529954
# Negative likelihood:  0.6590880903930094
# Negative likelihood:  1.7418638661118848
# Negative likelihood:  0.5031644383414959
# Negative likelihood:  3.1514197557827894
# Negative likelihood:  3.7695836965736205
# Negative likelihood:  0.9382212409128942
# Negative likelihood:  0.3538912474710039
# Negative likelihood:  2.273719316409877
# Negative likelihood:  0.6177774140913167
# Negative likelihood:  1.0855769517082017
# Negative likelihood:  0.7148249666634285
# Negative likelihood:  1.9734333188993536
# Negative likelihood:  1.3849110717563848
# Negative likelihood:  1.0644755045831675
# Negative likelihood:  0.3423325938463013
# Negative likelihood:  0.09680833887501475
# Negative likelihood:  0.19421115740329697
# Negative likelihood:  0.8417746123268472
# Negative likelihood:  0.24304359172840267
# Negative likelihood:  0.6841596702727339
# Negative likelihood:  0.690633924977168
# Negative likelihood:  1.1167879701043129
# Negative likelihood:  1.1820260457841525
# Negative likelihood:  1.326865180501607
# Negative likelihood:  1.5392485908721762
# Negative likelihood:  3.143890059197549
# Negative likelihood:  0.8416761657797032
# Negative likelihood:  0.38638241268570217
# Negative likelihood:  0.5121238176664024
# Negative likelihood:  2.277562810400453
# Negative likelihood:  3.7221886807426183
# Negative likelihood:  1.4676759052493187
# Negative likelihood:  0.8682549838019239
# Negative likelihood:  0.6507296302935746
# Negative likelihood:  1.153949487022129
# Negative likelihood:  0.5616681095142997
# Negative likelihood:  0.19779330034130552
# Negative likelihood:  1.3163816164292663
# Negative likelihood:  0.9027312769608101
# Negative likelihood:  1.274993349413733
# Negative likelihood:  0.6790059726260655
# Negative likelihood:  0.7140542195769123
# Negative likelihood:  0.44609875834999946
# Negative likelihood:  0.6281454753377018
# Negative likelihood:  3.042697487842632
# Negative likelihood:  0.8786569949131571
# Negative likelihood:  1.3178606409744404
# Negative likelihood:  0.15225271966865606
# Negative likelihood:  2.235481819070765
# Negative likelihood:  2.2561514060264463
# Negative likelihood:  1.8698442593821285
# Negative likelihood:  1.1990596597233802
# Negative likelihood:  0.2576953432851028
# Negative likelihood:  1.6364469105627153
# Negative likelihood:  0.41576280220049433
# Negative likelihood:  1.757370052329578
# Negative likelihood:  0.2603780953079717
# Progress:  0.4
# Negative likelihood:  0.8856016104389499
# Negative likelihood:  0.45661002135563594
# Negative likelihood:  0.3738762239970276
# Negative likelihood:  0.997667414281978
# Negative likelihood:  0.5904198664166336
# Negative likelihood:  0.37180485547386166
# Negative likelihood:  1.4000079991876586
# Negative likelihood:  1.2191093417545684
# Negative likelihood:  0.2520212289029213
# Negative likelihood:  1.2956226685738053
# Negative likelihood:  1.3144919037015308
# Negative likelihood:  0.40976212292324954
# Negative likelihood:  0.24724975393532733
# Negative likelihood:  0.09669498581570637
# Negative likelihood:  2.780259595290844
# Negative likelihood:  1.8411243042546201
# Negative likelihood:  2.1857663732178922
# Negative likelihood:  0.2871388868214629
# Negative likelihood:  3.8856165466898696
# Negative likelihood:  0.471771745333569
# Negative likelihood:  1.910620043888216
# Negative likelihood:  0.597301794041795
# Negative likelihood:  0.29045281730844613
# Negative likelihood:  0.284313010775522
# Negative likelihood:  0.6827990686328558
# Negative likelihood:  1.7867245299062569
# Negative likelihood:  1.0724460342218742
# Negative likelihood:  0.45610793416819045
# Negative likelihood:  1.6523703554019924
# Negative likelihood:  1.2300964848694582
# Negative likelihood:  0.9869599198795722
# Negative likelihood:  0.428223503291273
# Negative likelihood:  0.07990894215281681
# Negative likelihood:  1.0341544061500205
# Negative likelihood:  0.03660427635748223
# Negative likelihood:  0.07486131741867187
# Negative likelihood:  1.8553055278655406
# Negative likelihood:  0.24233079785041645
# Negative likelihood:  0.431901905752704
# Negative likelihood:  0.86740895067686
# Negative likelihood:  0.9451654727680042
# Negative likelihood:  0.092183040983745
# Negative likelihood:  0.21204900955054734
# Negative likelihood:  0.005790581533446733
# Negative likelihood:  0.7885559259248465
# Negative likelihood:  0.021199544240420223
# Negative likelihood:  0.16266072076493496
# Negative likelihood:  0.04816950999373365
# Negative likelihood:  0.046984645037263205
# Negative likelihood:  0.011224957411466176
# Negative likelihood:  0.035854335183000866
# Negative likelihood:  0.8007204540051395
# Negative likelihood:  0.23959090357059562
# Negative likelihood:  0.19894600540659557
# Negative likelihood:  0.07093004758194135
# Negative likelihood:  0.005684046170273121
# Negative likelihood:  0.0014782665056367289
# Negative likelihood:  0.4385466816397569
# Negative likelihood:  1.1920280293696468
# Negative likelihood:  2.2555265277780197
# Negative likelihood:  0.002554436129040699
# Negative likelihood:  1.0690320985744803
# Negative likelihood:  0.1757752735257447
# Negative likelihood:  0.45919588230511227
# Negative likelihood:  0.08535360599770389
# Negative likelihood:  2.0929624630438295
# Negative likelihood:  0.7608370791457214
# Negative likelihood:  1.3179297661109173
# Negative likelihood:  0.2460788897256952
# Negative likelihood:  0.952132768441358
# Negative likelihood:  0.24840510781114758
# Negative likelihood:  1.831495179898062
# Negative likelihood:  3.3138524237098137
# Negative likelihood:  0.1723549334631611
# Negative likelihood:  0.8337878436910005
# Negative likelihood:  2.1315852928447137
# Negative likelihood:  0.2610985911017121
# Negative likelihood:  0.5918601681140063
# Negative likelihood:  0.5143141353520123
# Negative likelihood:  0.37653259443298864
# Negative likelihood:  2.741143514455504
# Negative likelihood:  1.338152374836122
# Negative likelihood:  1.6976376343695256
# Negative likelihood:  0.03763417251971911
# Negative likelihood:  2.299002002620376
# Negative likelihood:  0.5732404771246894
# Negative likelihood:  0.3119212496310138
# Negative likelihood:  0.6439308126742272
# Negative likelihood:  2.834531364500909
# Negative likelihood:  0.7784195076933602
# Negative likelihood:  0.7712157027760436
# Negative likelihood:  0.19476594538819517
# Negative likelihood:  0.6386831146332311
# Negative likelihood:  0.26632246140799687
# Negative likelihood:  3.5093304140242685
# Negative likelihood:  0.13364487777263687
# Negative likelihood:  0.263748331761408
# Negative likelihood:  1.0128970717156873
# Negative likelihood:  2.5532329599037933
# Negative likelihood:  0.19467502179591634
# Negative likelihood:  0.7641868024039286
# Negative likelihood:  0.7933904611540288
# Negative likelihood:  1.2087722823329383
# Negative likelihood:  0.04718212055109332
# Negative likelihood:  2.196717769218054
# Negative likelihood:  3.8707800876458682
# Negative likelihood:  1.4772489017122281
# Negative likelihood:  1.0204378255722935
# Negative likelihood:  0.11726578536007021
# Negative likelihood:  0.005299692594290787
# Negative likelihood:  0.010855721271005068
# Negative likelihood:  0.11715099068819947
# Negative likelihood:  0.016860265184267042
# Negative likelihood:  0.22853743838926852
# Progress:  0.5
# Negative likelihood:  0.39474811462968806
# Negative likelihood:  0.8087961858669777
# Negative likelihood:  0.9169956286495811
# Negative likelihood:  0.8659131975002407
# Negative likelihood:  4.271385117013906
# Negative likelihood:  0.1986175715072958
# Negative likelihood:  0.0607811520010557
# Negative likelihood:  0.836989160036408
# Negative likelihood:  0.26955602691824276
# Negative likelihood:  0.26133408395932106
# Negative likelihood:  0.3362230180923706
# Negative likelihood:  0.15785076149092528
# Negative likelihood:  2.1593097242055728
# Negative likelihood:  0.40346938796290865
# Negative likelihood:  0.21962783101387692
# Negative likelihood:  1.3264634555605497
# Negative likelihood:  2.7749591127253534
# Negative likelihood:  0.0018269694548573377
# Negative likelihood:  0.001978207367877854
# Negative likelihood:  0.12566861256873374
# Negative likelihood:  0.6501331209675897
# Negative likelihood:  2.7948835610527687
# Negative likelihood:  1.6790531742264276
# Negative likelihood:  2.1429071225998277
# Negative likelihood:  0.14834805624063363
# Negative likelihood:  0.4527991076450405
# Negative likelihood:  0.5209227490746681
# Negative likelihood:  0.2964680953637879
# Negative likelihood:  3.8508633430889367
# Negative likelihood:  1.10883463738665
# Negative likelihood:  0.6325513280865672
# Negative likelihood:  0.3307549552270488
# Negative likelihood:  0.36584586450053386
# Negative likelihood:  0.8808500944687475
# Negative likelihood:  0.909685245944969
# Negative likelihood:  0.003992227612074078
# Negative likelihood:  0.8596063097250928
# Negative likelihood:  2.6245289954539195
# Negative likelihood:  0.48143987336865823
# Negative likelihood:  0.1443166257458931
# Negative likelihood:  1.9410428003275777
# Negative likelihood:  0.6759635840931798
# Negative likelihood:  0.46465063366047665
# Negative likelihood:  0.9162498945848534
# Negative likelihood:  0.06602054654180117
# Negative likelihood:  0.18293557603617025
# Negative likelihood:  1.1043998815261384
# Negative likelihood:  0.6247498613194051
# Negative likelihood:  1.4198020199534072
# Negative likelihood:  1.3633622189957972
# Negative likelihood:  0.01965843662739838
# Negative likelihood:  0.04032642316849622
# Negative likelihood:  1.3013714262826392
# Negative likelihood:  0.11483755983501318
# Negative likelihood:  1.234042441166708
# Negative likelihood:  0.22994012176128967
# Negative likelihood:  0.40167485427388744
# Negative likelihood:  0.19758153674532977
# Negative likelihood:  0.6625582959326753
# Negative likelihood:  0.24493664400445123
# Negative likelihood:  0.6522148833022192
# Negative likelihood:  0.7419145204091696
# Negative likelihood:  0.1366341595026753
# Negative likelihood:  1.095373198718586
# Negative likelihood:  0.47573187389630894
# Negative likelihood:  1.8322689509054964
# Negative likelihood:  0.1404451746923916
# Negative likelihood:  0.9441604747711686
# Negative likelihood:  2.037257055551967
# Negative likelihood:  0.6198920431322351
# Negative likelihood:  1.5074553122807808
# Negative likelihood:  0.7553847429188617
# Negative likelihood:  0.5634236206182608
# Negative likelihood:  0.3953711029873324
# Negative likelihood:  0.010874087757656066
# Negative likelihood:  1.645396696629185
# Negative likelihood:  2.5799552269268853
# Negative likelihood:  0.3324946118039708
# Negative likelihood:  0.07091168071429356
# Negative likelihood:  0.004206513431530881
# Negative likelihood:  0.06920275444744832
# Negative likelihood:  0.05637244771402342
# Negative likelihood:  3.7752840527281126
# Negative likelihood:  1.394056440997325
# Negative likelihood:  0.9194419460632661
# Negative likelihood:  1.1620166610181575
# Negative likelihood:  0.9561807977672149
# Negative likelihood:  0.32316124588717693
# Negative likelihood:  1.0358762740714054
# Negative likelihood:  1.182310212487838
# Negative likelihood:  0.6355603508186911
# Negative likelihood:  0.6290936226529296
# Negative likelihood:  0.7322669231375575
# Negative likelihood:  1.284640688812822
# Negative likelihood:  2.2970741974976967
# Negative likelihood:  0.1434641925775578
# Negative likelihood:  0.9285193852665654
# Negative likelihood:  2.0519037381736194
# Negative likelihood:  2.7129039327682456
# Negative likelihood:  2.112173170973671
# Negative likelihood:  0.009908618878434477
# Negative likelihood:  1.212230510812143
# Negative likelihood:  0.08434432712155855
# Negative likelihood:  0.33715129427960994
# Negative likelihood:  1.2322471161195339
# Negative likelihood:  0.2494142727134706
# Negative likelihood:  2.890466890665629
# Negative likelihood:  0.22901768135563666
# Negative likelihood:  0.2349975272782062
# Negative likelihood:  3.2676042743238325
# Negative likelihood:  2.230885759854472
# Negative likelihood:  0.3761050847993762
# Negative likelihood:  0.38251236896058344
# Negative likelihood:  1.4759896044197514
# Progress:  0.6
# Negative likelihood:  0.1512019983051508
# Negative likelihood:  2.976765619422226
# Negative likelihood:  0.19364198846275424
# Negative likelihood:  0.31831850784496674
# Negative likelihood:  0.10990615098532645
# Negative likelihood:  0.32311189760840703
# Negative likelihood:  4.429569002365148
# Negative likelihood:  0.4284035089582478
# Negative likelihood:  1.2421424611845688
# Negative likelihood:  0.07716466717770777
# Negative likelihood:  1.8698277666112766
# Negative likelihood:  0.27041281031141634
# Negative likelihood:  0.650839125065105
# Negative likelihood:  0.1445818648625552
# Negative likelihood:  0.9422299772515201
# Negative likelihood:  0.8988025821160005
# Negative likelihood:  0.2729644802811336
# Negative likelihood:  3.420573985286107
# Negative likelihood:  1.2401754243759964
# Negative likelihood:  0.2521460514284584
# Negative likelihood:  1.3303220014475932
# Negative likelihood:  1.1665737268284184
# Negative likelihood:  0.5859981494302925
# Negative likelihood:  0.5672322272993625
# Negative likelihood:  0.658102276863785
# Negative likelihood:  0.15463815294832128
# Negative likelihood:  0.5751902323349761
# Negative likelihood:  0.41922965326188877
# Negative likelihood:  1.2157355940218952
# Negative likelihood:  0.9809046933802307
# Negative likelihood:  0.8019645474215009
# Negative likelihood:  1.2029590313699297
# Negative likelihood:  0.7536000920181615
# Negative likelihood:  2.093008453289138
# Negative likelihood:  1.5729244404763405
# Negative likelihood:  0.15972382848379674
# Negative likelihood:  1.1759195143473222
# Negative likelihood:  0.6785179798695611
# Negative likelihood:  2.0812134924490016
# Negative likelihood:  0.24315893583759823
# Negative likelihood:  0.2580347276842758
# Negative likelihood:  2.811243680884739
# Negative likelihood:  0.01906612009499813
# Negative likelihood:  0.006953979379087437
# Negative likelihood:  0.43219519249172805
# Negative likelihood:  0.0803378546271543
# Negative likelihood:  0.13293300521248386
# Negative likelihood:  4.4353342783397185
# Negative likelihood:  1.0086942445849831
# Negative likelihood:  0.3347473207753821
# Negative likelihood:  0.025516008636483366
# Negative likelihood:  0.7835020537626278
# Negative likelihood:  0.2318648152313078
# Negative likelihood:  0.2597838956493133
# Negative likelihood:  0.14153926508818054
# Negative likelihood:  2.9989829308652065
# Negative likelihood:  1.5292157810337055
# Negative likelihood:  2.0043605570263336
# Negative likelihood:  0.22032087013155588
# Negative likelihood:  1.5458566296885203
# Negative likelihood:  0.5003534828975275
# Negative likelihood:  0.6959956391825984
# Negative likelihood:  1.6548850176226906
# Negative likelihood:  0.8805264523812497
# Negative likelihood:  0.23018650946490388
# Negative likelihood:  0.14032086406354075
# Negative likelihood:  0.5313360390655838
# Negative likelihood:  0.9739106676717357
# Negative likelihood:  0.5237877754722483
# Negative likelihood:  1.087517562879006
# Negative likelihood:  0.03712260096383329
# Negative likelihood:  0.4328527299399339
# Negative likelihood:  0.9450908741856554
# Negative likelihood:  0.2698479848156209
# Negative likelihood:  0.5796598048459951
# Negative likelihood:  0.01942092523327321
# Negative likelihood:  1.3749006842606266
# Negative likelihood:  1.9114831393230518
# Negative likelihood:  0.38398979359490976
# Negative likelihood:  0.06878745910076825
# Negative likelihood:  1.578020077206234
# Negative likelihood:  0.8211534798512784
# Negative likelihood:  1.0482766978122497
# Negative likelihood:  0.2818085246352209
# Negative likelihood:  2.170596900286297
# Negative likelihood:  0.3221766153693941
# Negative likelihood:  1.2349154396528617
# Negative likelihood:  2.5765842104658137
# Negative likelihood:  1.3918896698256076
# Negative likelihood:  0.014945859199096637
# Negative likelihood:  0.03456256517464129
# Negative likelihood:  0.854986586392399
# Negative likelihood:  1.504812806904417
# Negative likelihood:  0.7437783505813571
# Negative likelihood:  0.18746435645354154
# Negative likelihood:  0.9458518427069094
# Negative likelihood:  0.18473063601918774
# Negative likelihood:  3.6158181056754795
# Negative likelihood:  0.08280572594035035
# Negative likelihood:  1.4183557733795553
# Negative likelihood:  0.34920518437884995
# Negative likelihood:  0.43544313639327237
# Negative likelihood:  0.26381781074081506
# Negative likelihood:  1.920440749558728
# Negative likelihood:  0.3735627966502059
# Negative likelihood:  1.9535114216817178
# Negative likelihood:  0.16019141981320895
# Negative likelihood:  0.42624295347596414
# Negative likelihood:  0.02216471271755057
# Negative likelihood:  2.032343353140168
# Negative likelihood:  0.05713773616813911
# Negative likelihood:  0.19057067871592337
# Negative likelihood:  0.533944550091692
# Negative likelihood:  2.5711655168749368
# Progress:  0.7
# Negative likelihood:  0.6370036768178532
# Negative likelihood:  1.8283090360471907
# Negative likelihood:  0.6448466736734267
# Negative likelihood:  0.29259467410079143
# Negative likelihood:  0.6204508826608256
# Negative likelihood:  0.5102164799503696
# Negative likelihood:  0.5050922248511263
# Negative likelihood:  0.6621092408355622
# Negative likelihood:  0.9923593552846368
# Negative likelihood:  0.17975602072771332
# Negative likelihood:  1.6329165662383711
# Negative likelihood:  1.8942881491356605
# Negative likelihood:  0.2926086583694692
# Negative likelihood:  0.7433035674536492
# Negative likelihood:  1.383145167696545
# Negative likelihood:  2.5292146302665515
# Negative likelihood:  1.1560223348043723
# Negative likelihood:  1.6044457606940448
# Negative likelihood:  0.7865954555910372
# Negative likelihood:  0.3619896968897356
# Negative likelihood:  0.4398113284922537
# Negative likelihood:  0.8012781910961952
# Negative likelihood:  3.792332027892976
# Negative likelihood:  0.18890784436484717
# Negative likelihood:  0.10096640567492617
# Negative likelihood:  0.015149251012208856
# Negative likelihood:  1.0978828502877174
# Negative likelihood:  0.1234511591769319
# Negative likelihood:  5.771646823964142
# Negative likelihood:  0.341914330346787
# Negative likelihood:  2.21570019321134
# Negative likelihood:  1.2203130724191746
# Negative likelihood:  1.5470188197807486
# Negative likelihood:  1.880848817912345
# Negative likelihood:  0.8466653092555445
# Negative likelihood:  1.7817440663444353
# Negative likelihood:  1.238413290215391
# Negative likelihood:  0.05242722019928593
# Negative likelihood:  0.6688106152732878
# Negative likelihood:  3.683774122499918
# Negative likelihood:  0.6460843611679064
# Negative likelihood:  2.0700525241459986
# Negative likelihood:  0.8117791968282335
# Negative likelihood:  0.3365062107103414
# Negative likelihood:  0.29109686494284354
# Negative likelihood:  0.21164940378929936
# Negative likelihood:  1.2228193126579332
# Negative likelihood:  0.030506122803741945
# Negative likelihood:  0.039343400396093055
# Negative likelihood:  0.0034366257816176855
# Negative likelihood:  0.010691299811367776
# Negative likelihood:  0.014730982879778063
# Negative likelihood:  0.0044790655366070955
# Negative likelihood:  0.0056667913160585075
# Negative likelihood:  0.6323948571889922
# Negative likelihood:  0.8814266513269001
# Negative likelihood:  0.45543196693717475
# Negative likelihood:  0.475497659909988
# Negative likelihood:  1.3890652887457542
# Negative likelihood:  3.238691566229873
# Negative likelihood:  0.92667544348674
# Negative likelihood:  0.19048146329807217
# Negative likelihood:  0.16712807156190845
# Negative likelihood:  0.10630205091291643
# Negative likelihood:  0.28490205579614714
# Negative likelihood:  1.0598281134119873
# Negative likelihood:  0.3083137283791141
# Negative likelihood:  2.616889850907381
# Negative likelihood:  0.5826162827315662
# Negative likelihood:  1.6933741199212464
# Negative likelihood:  1.0777613626059817
# Negative likelihood:  0.22674588064200696
# Negative likelihood:  0.5789689540836066
# Negative likelihood:  0.6085408790433185
# Negative likelihood:  2.0921117243093637
# Negative likelihood:  1.0227425907522598
# Negative likelihood:  1.3389066679362176
# Negative likelihood:  0.7218354769635714
# Negative likelihood:  0.608466636244928
# Negative likelihood:  1.9708396546941114
# Negative likelihood:  2.790435044155414
# Negative likelihood:  2.234086588203078
# Negative likelihood:  0.08511061336447939
# Negative likelihood:  1.1429389977166047
# Negative likelihood:  2.242512055653323
# Negative likelihood:  2.3692253823062353
# Negative likelihood:  0.746306895318825
# Negative likelihood:  0.12814116104815307
# Negative likelihood:  0.4781614047956194
# Negative likelihood:  0.21936697808821007
# Negative likelihood:  1.2936930112544556
# Negative likelihood:  0.5138192296704471
# Negative likelihood:  0.7347450979299954
# Negative likelihood:  0.2851303297777579
# Negative likelihood:  0.2859213890925003
# Negative likelihood:  0.09892775316140986
# Negative likelihood:  0.32573256150454366
# Negative likelihood:  0.16346717152771545
# Negative likelihood:  0.3394133362977324
# Negative likelihood:  0.466639139064033
# Negative likelihood:  0.4999502837345358
# Negative likelihood:  1.232030719883173
# Negative likelihood:  0.8190617520119223
# Negative likelihood:  1.901087260567376
# Negative likelihood:  0.7342596507791732
# Negative likelihood:  0.7766210326178216
# Negative likelihood:  0.4118243348380932
# Negative likelihood:  0.18902390013746323
# Negative likelihood:  0.1405146022948187
# Negative likelihood:  3.0127618902192417
# Negative likelihood:  3.0677474079062703
# Negative likelihood:  0.31442056454377015
# Negative likelihood:  0.18527210025511273
# Negative likelihood:  0.2277052555328011
# Progress:  0.8
# Negative likelihood:  1.2570928568538093
# Negative likelihood:  0.6236424353062469
# Negative likelihood:  0.8095402144190149
# Negative likelihood:  1.032344643992802
# Negative likelihood:  0.27680839436362814
# Negative likelihood:  0.05011331908398653
# Negative likelihood:  0.11698345578455986
# Negative likelihood:  0.16965655871797983
# Negative likelihood:  1.3083106860876264
# Negative likelihood:  0.005967893514325538
# Negative likelihood:  1.748063834884812
# Negative likelihood:  2.75976921028941
# Negative likelihood:  0.08160768032896487
# Negative likelihood:  2.445250310444303
# Negative likelihood:  0.26145624262552736
# Negative likelihood:  2.815596387329651
# Negative likelihood:  1.4225635767446918
# Negative likelihood:  0.458558203709527
# Negative likelihood:  0.5746240452130792
# Negative likelihood:  0.5562175968290343
# Negative likelihood:  0.8133025276830147
# Negative likelihood:  0.41310124079278326
# Negative likelihood:  0.04349438375656258
# Negative likelihood:  0.25497851174879915
# Negative likelihood:  1.6280414699335535
# Negative likelihood:  3.3789855483165456
# Negative likelihood:  3.5334723386208027
# Negative likelihood:  0.948141040699493
# Negative likelihood:  1.1637418214783137
# Negative likelihood:  0.07037471035024816
# Negative likelihood:  0.652809098208289
# Negative likelihood:  0.5159797573374899
# Negative likelihood:  0.44847458391671247
# Negative likelihood:  0.4161648513490721
# Negative likelihood:  0.22032695118530016
# Negative likelihood:  1.9339549283212276
# Negative likelihood:  0.20852348453067124
# Negative likelihood:  0.8481282570110925
# Negative likelihood:  0.8609198998813998
# Negative likelihood:  2.4387205578326205
# Negative likelihood:  0.13618539818787237
# Negative likelihood:  0.3014929201453703
# Negative likelihood:  0.1053850911300035
# Negative likelihood:  0.057501906469286324
# Negative likelihood:  0.1660202418102426
# Negative likelihood:  0.056838174628748794
# Negative likelihood:  0.6330474660141736
# Negative likelihood:  0.12089310747240599
# Negative likelihood:  1.9119642092005367
# Negative likelihood:  0.7686693104380186
# Negative likelihood:  1.1818800612266525
# Negative likelihood:  0.0477259495539796
# Negative likelihood:  1.703447441745238
# Negative likelihood:  1.2565871797784782
# Negative likelihood:  1.1675943196358647
# Negative likelihood:  1.2338305085204566
# Negative likelihood:  4.525133103207036
# Negative likelihood:  0.24167782599657636
# Negative likelihood:  0.45710139523516263
# Negative likelihood:  0.152801473566998
# Negative likelihood:  1.6338433089996054
# Negative likelihood:  0.6019373812466308
# Negative likelihood:  1.5961723974192856
# Negative likelihood:  0.6138909426057332
# Negative likelihood:  0.38855691764682354
# Negative likelihood:  0.060942209200142386
# Negative likelihood:  0.8970087039919199
# Negative likelihood:  0.816795527941309
# Negative likelihood:  0.6202454127061241
# Negative likelihood:  0.06445281661726696
# Negative likelihood:  0.1432071537733175
# Negative likelihood:  0.0637838819023594
# Negative likelihood:  0.017812688347186807
# Negative likelihood:  0.016237761431740244
# Negative likelihood:  0.700684039135935
# Negative likelihood:  4.4679415381539975
# Negative likelihood:  0.3541312941104642
# Negative likelihood:  1.1192912828097077
# Negative likelihood:  0.07785300657236496
# Negative likelihood:  0.0006780718918284882
# Negative likelihood:  0.04904673956318455
# Negative likelihood:  0.07487951750922904
# Negative likelihood:  0.20713662553019888
# Negative likelihood:  0.537451585477262
# Negative likelihood:  0.08767748974383449
# Negative likelihood:  0.31737991414681466
# Negative likelihood:  0.007381618404220975
# Negative likelihood:  0.001457133577724872
# Negative likelihood:  0.4130145432048073
# Negative likelihood:  0.01704280751965697
# Negative likelihood:  0.2026890428625208
# Negative likelihood:  0.001869920314829258
# Negative likelihood:  0.17206300825534251
# Negative likelihood:  0.01961831910375138
# Negative likelihood:  0.3093477266493688
# Negative likelihood:  0.004955253049388484
# Negative likelihood:  0.09468842415735872
# Negative likelihood:  0.0005711261516417652
# Negative likelihood:  0.3356569558242498
# Negative likelihood:  0.0015001616365201747
# Negative likelihood:  0.05217864528252489
# Negative likelihood:  0.13784203866491324
# Negative likelihood:  0.015360216989182152
# Negative likelihood:  0.0822360407115307
# Negative likelihood:  0.08322777045643337
# Negative likelihood:  0.022180387420388387
# Negative likelihood:  0.1551062090032196
# Negative likelihood:  0.11092047912954416
# Negative likelihood:  0.0005151755043340334
# Negative likelihood:  0.2819572894480886
# Negative likelihood:  0.12672356964082826
# Negative likelihood:  1.8860023493122986
# Negative likelihood:  2.2692623167141326
# Negative likelihood:  0.3885245389046346
# Progress:  0.9
# Negative likelihood:  0.3262066902544796
# Negative likelihood:  0.9959074633971426
# Negative likelihood:  0.885135107843058
# Negative likelihood:  0.9224110033282021
# Negative likelihood:  1.2962711121491937
# Negative likelihood:  0.07972791980212932
# Negative likelihood:  0.8897102216402538
# Negative likelihood:  1.754214786775686
# Negative likelihood:  0.04398595919020184
# Negative likelihood:  0.3081300502065712
# Negative likelihood:  4.993420011065381
# Negative likelihood:  0.29334484379031156
# Negative likelihood:  1.2000028038526744
# Negative likelihood:  0.0075775207703880874
# Negative likelihood:  0.04335297789322617
# Negative likelihood:  0.0008571986150563927
# Negative likelihood:  0.15983268813957208
# Negative likelihood:  0.054417887693822144
# Negative likelihood:  0.4596834038806107
# Negative likelihood:  0.5995471879229844
# Negative likelihood:  0.7358811506957625
# Negative likelihood:  1.0843488230265177
# Negative likelihood:  1.249318427232019
# Negative likelihood:  5.232202956027305
# Negative likelihood:  1.2636163690006015
# Negative likelihood:  0.2877349879760492
# Negative likelihood:  0.49559081957495593
# Negative likelihood:  0.9495844821470504
# Negative likelihood:  2.4709090916577603
# Negative likelihood:  0.23766665854038108
# Negative likelihood:  0.656292289869372
# Negative likelihood:  0.6136110995639676
# Negative likelihood:  0.4962218173036948
# Negative likelihood:  1.3313349655470903
# Negative likelihood:  0.08525018126286527
# Negative likelihood:  0.03104744713121822
# Negative likelihood:  1.0455767488777619
# Negative likelihood:  0.42210562337926116
# Negative likelihood:  0.9030763805678684
# Negative likelihood:  0.28878053401309484
# Negative likelihood:  1.5575704752102866
# Negative likelihood:  0.041738756402430466
# Negative likelihood:  0.12092306092621799
# Negative likelihood:  0.036046253573789704
# Negative likelihood:  0.3415813710419715
# Negative likelihood:  2.1935752256196333
# Negative likelihood:  0.11629946539152301
# Negative likelihood:  0.5822372543900787
# Negative likelihood:  0.16082267619725027
# Negative likelihood:  0.18126411252369728
# Negative likelihood:  0.0763592282620891
# Negative likelihood:  1.5538962207836589
# Negative likelihood:  0.021167224065749057
# Negative likelihood:  0.5381872433673344
# Negative likelihood:  0.039327358329387115
# Negative likelihood:  0.11941728553382
# Negative likelihood:  0.0314824893936112
# Negative likelihood:  0.07716666805119701
# Negative likelihood:  0.04123667986808072
# Negative likelihood:  3.6422329955182686
# Negative likelihood:  1.1173771468522282
# Negative likelihood:  0.5155600225729078
# Negative likelihood:  0.10334022565696384
# Negative likelihood:  0.618804619125686
# Negative likelihood:  1.2368997409885005
# Negative likelihood:  0.16717782974250475
# Negative likelihood:  0.7245748653394588
# Negative likelihood:  0.16302615521597477
# Negative likelihood:  0.050594079850679693
# Negative likelihood:  0.5362763316159566
# Negative likelihood:  0.7281971673690415
# Negative likelihood:  0.6573800179449343
# Negative likelihood:  1.299885267329667
# Negative likelihood:  0.19816761328822646
# Negative likelihood:  0.11889132364198943
# Negative likelihood:  0.4457635582686002
# Negative likelihood:  0.09314545593487246
# Negative likelihood:  0.7880336918874014
# Negative likelihood:  0.24943252254342915
# Negative likelihood:  0.016045499181423586
# Negative likelihood:  1.1314546389129818
# Negative likelihood:  0.1752947890327761
# Negative likelihood:  0.39071913704971134
# Negative likelihood:  0.3845522775092038
# Negative likelihood:  0.17680710138885342
# Negative likelihood:  0.35020806219645806
# Negative likelihood:  0.867075014600718
# Negative likelihood:  0.8873912086426128
# Negative likelihood:  0.039018428082285034
# Negative likelihood:  0.40269027105561955
# Negative likelihood:  0.6843895660380653
# Negative likelihood:  2.5777574839971495
# Negative likelihood:  0.8310449639145876
# Negative likelihood:  1.2208218315578077
# Negative likelihood:  1.0094529379876584
# Negative likelihood:  0.32397984983139
# Negative likelihood:  1.1647556837389255
# Negative likelihood:  0.29784013612319804
# Negative likelihood:  0.22824876586746573
# Negative likelihood:  0.49396344832848466
# Negative likelihood:  0.2185365047291147
# Negative likelihood:  0.33861982867474016
# Negative likelihood:  0.13668610389654293
# Negative likelihood:  0.05127778532960529
# Negative likelihood:  0.06989949790685251
# Negative likelihood:  2.1476481491535253
# Negative likelihood:  1.1173231801766876
# Negative likelihood:  0.8587204384424189
# Negative likelihood:  0.14107375081671533
# Negative likelihood:  0.12651947279036807
# Negative likelihood:  0.1556354775076546
# Negative likelihood:  0.20551506670368933
# Negative likelihood:  0.6072173048029206
# Negative likelihood:  0.05883856455679727
# Epoch:  1
# Negative likelihood:  1.1517668843581117
# Negative likelihood:  0.6769003991566881
# Negative likelihood:  1.8121837604891544
# Negative likelihood:  1.1975575256675068
# Negative likelihood:  0.8464189513188071
# Negative likelihood:  2.3839997784830236
# Negative likelihood:  0.06701998839360994
# Negative likelihood:  2.0008285489608943
# Negative likelihood:  2.579830107801237
# Negative likelihood:  0.2785107923376028
# Negative likelihood:  0.11423358969908098
# Negative likelihood:  2.975774440164657
# Negative likelihood:  0.6638711779016757
# Negative likelihood:  1.5784861079405037
# Negative likelihood:  0.024706822664040656
# ...
# 0.03549670176738126
# 0.027357144339742272
# 0.29307800594187355
# 1.322649040526674
# 1.4994329967806426
# 0.36253133283959244
# 0.29973194708189393
# 0.002361313097117421
# 0.008518840340380895
# 0.028208526966026957
# 0.5374023165559757
# 0.004518702678064798
# 1.9897592533125208
# 2.1947550101490334
# 0.2893886567736785
# 0.5509734520784803
# 0.07475876901048928
# 0.5630689528617743
# 1.7278668647671274
# 1.2183913280768972
# 0.1829084578149801
# 0.2213005217496635
# 0.009894292379420286
# 0.6138043937099692
# 0.8267047960949868
# 0.4541688692995885
# 1.9564630268265601
# 0.14130880261311404
# 0.7398230685396014
# 2.939208721701507
# 0.6374627377144927
# 0.13492172133958522
# 0.8780864158500825
# 0.1644007551969725
# 0.7173446003393096
# 0.0914303120777121
# 2.555708799201812
# 2.1193162371000915
# 0.3734243170629981
# 0.5732818656596427
# 0.5253701692813944
# 0.1365021091442789
# 0.0021737705275869587
# 1.8514059932221918
# 0.606778173996157
# 0.20671966512632403
# 0.058573143255497576
# 2.2232388973827266
# 1.0124094577051461
# 0.5310783359763246
# 0.9111495773817289
# 1.470092387954832
# 2.5860793430775857
# 0.9988254224501726
# 5.98214054110048
# 0.27365133873226305
# 0.7988911769889784
# 0.14200179005993263
# 1.9163656425054287
# 0.38960330580457514
# 0.5883195232780486
# 0.020120750280962503
# 0.07620310270579804
# 0.3813990054340638
# 0.011077436240429426
# 0.22755703685065354
# 0.9263266749910634
# 1.9845694200399189
# 2.6868442820885914
# 0.7734608385322218
# 2.217904853188232
# 1.9558781519332293
# 0.8908494789705416
# 0.08303865059073878
# 0.06255640153906768
# 0.6239581369247333
# 0.03797408002195677
# 0.18925152041028656
# 0.6913758702723064
# 0.05483531544091047
# 0.5373431180443927
# 0.1176709720612486
# 0.12117007819292873
# 0.20850195485641387
# 0.09440481825885853
# 1.3813352365804197
# 0.1450332072270357
# 1.056565457695795
# 0.4077068895689638
# 0.656896030843312
# 0.8399164051483654
# 1.5200810465791375
# 0.1405275511198393
# 3.5675577836319214
# 1.769564402363286
# 0.5939506135121504
# 0.4540128328909725
# 1.4822578204328372
# 0.3184917921771847
# 0.6906934985766493
# 0.9557028968635382
# 0.10072823138893407
# 0.9805673924536248
# 0.5385530885762096
# 0.028818782505088847
# 3.7711202023548225
# 0.5270541839798623
# 0.28114951180070163
# 0.9954905818957573
# 0.906167960384042
# 0.49031089261282806
# 1.1145932254340374
# 0.7117906302924623
# 0.2619131232938444
# 3.2648016302631993
# 2.5241713299269923
# 3.548206115172455
# 0.06788454547446592
# 0.26754882609192143
# 0.6980998115161938
# 2.0126622770028777
# 1.0402233634645774
# 0.6417094755239909
# 1.0555962338150198
# 1.2509237079623778
# 0.8057963459471571
# 1.174805746451563
# 1.4011018816778937
# 1.437194271203791
# 2.115339835161405
# 1.7825792494629566
# 0.25877885549270935
# 0.672472858324173
# 0.8437161943678783
# 0.7124622220927733
# 0.2161252625107592
# 0.27010480544364807
# 1.41789771550804
# 0.5530706729667381
# 0.20323319365551087
# 1.4064104522813439
# 0.6492021801866109
# 0.6839567861943884
# 0.0009288815904776999
# 0.029672177390619274
# 1.6512106509028792
# 2.0660007364090403
# 0.7560030182250354
# 3.7069910221082143
# 2.641992253978728
# 0.33419791812208755
# 0.09551141495292467
# 0.24501650344451306
# 0.8332184710622706
# 0.15175753654004046
# 1.4985294084836007
# 0.7999410715188463
# 0.1326611446547984
# 0.5199862776694125
# 1.151580717568939
# 0.32930483562900154
# 1.3617196474580495
# 0.8595283361303041
# 0.8516653543593711
# 0.5362205636831429
# 0.16020456872649824
# 2.1059743184478132
# 1.1603985576275009
# 1.3101071916319367
# 0.0904014718002672
# 1.5081889689114425
# 1.4014267752196923
# 1.5961318385789312
# 1.0993748308393874
# 0.3178107766175318
# 1.1370059419631484
# 0.6974709295526642
# 1.0379753700457497
# 0.3543784461285875
# 1.8970978020471618
# 1.2577650825639874
# 1.6581528726754664
# 0.1814885864858629
# 0.188294962692177
# 5.201467435069428
# 4.081536490097793
# 0.3835293046423997
# 0.01142203281007789
# 0.0022586440960837718
# 0.002853484604611212
# 0.014645707006998097
# 0.047803413726140796
# 0.12164741677455357
# 0.027905228466930297
# 0.006320942312551541
# 4.663137605864669
# 0.9501120512981802
# 0.37084193813472843
# 0.01786806735146774
# 1.0156560257939151
# 0.36822464215944034
# 1.7547355834005123
# 0.5406834728729345
# 0.04796616301270961
# 2.225165742876649
# 1.8177841942450805
# 0.41591878338970195
# 0.768531946643871
# 0.7887127070056847
# 2.4075643535316438
# 0.2628720335271974
# 1.4376334696476603
# 0.41442170776725895
# 1.4155751844067301
# 0.013062504028217709
# 1.1303026264498572
# 0.07295649403583541
# 0.9685205625809554
# 0.879153620051218
# 0.8085095832412547
# 2.5557035374539514
# 3.2398257279925815
# 0.4953877621551417
# 1.312012259596787
# 1.286067206884825
# 0.9128850532858199
# 0.13352700609138235
# 0.3721610936376482
# 1.0807751493415743
# 1.739538497936713
# 1.065825507410327
# 1.2722372486384346
# 0.5116265577511988
# 1.9864280616328875
# 0.3909092650974019
# 1.0894546624881063
# 0.4890306955360827
# 0.29548422946738895
# 0.8098571544187481
# 0.49256184361876443
# 0.2565561820436587
# 0.5250327882195419
# 3.48131299952308
# 0.9337393092031585
# 0.9544652845514298
# 0.42814443541267766
# 1.2089200683496695
# 0.04486614835269631
# 0.2136944908471593
# 2.605732269361138
# 0.9336530938662496
# 0.5592079741064996
# 0.05125047629105502
# 0.0229255720602556
# 0.006975237171597985
# 10.70353144322363
# 3.7073225137768167
# 2.3381191991390833
# 0.20603691332044338
# 0.34057826464945945
# 4.173954160704147
# 0.07438455231606818
# 0.25613758215847987
# 0.35529321246313783
# 3.4157077368730167
# 0.3089314236299818
# 0.1340338521434065
# 0.8275047337095578
# 0.0568040662792382
# 0.18818057611790773
# 0.30689684238474224
# 0.4973460887066051
# 1.1944362849696384
# 1.082476631948947
# 2.360251458289541
# 0.09557997550243605
# 0.29668948829916475
# 0.3579238029731103
# 0.2309623653011186
# 0.10923249436098958
# 0.338194835728235
# 1.0381624566813876
# 0.5631220342842462
# 0.0442254490260799
# 1.2402565403413386
# 0.2646272057024902
# 1.0668519762202513
# 2.4994209527807425
# 0.08489691529430521
# 3.0333639254577673
# 0.12516279124382915
# 0.14730344062092277
# 0.087851785673589
# 0.10920162469521273
# 0.9226774998075367
# 1.9768168103791943
# 1.2042850428171834
# 0.005687189741188232
# 1.3753836403397224
# 0.021474975197385286
# 0.40858320793265207
# 0.5168785359578837
# 0.30751082005453234
# 0.4780693697480828
# 1.0106833083512303
# 0.3975297015884752
# 0.8303368183096258
# 0.1262669853776916
# 1.488782793982269
# 1.4955849745603151
# 0.09437373414129954
# 0.003471797289409975
# 1.2505880743775786
# 0.08676875032192585
# 0.4915056624689307
# 1.8891731340181626
# 1.2974200829847962
# 0.23986360803786613
# 0.07635816268530364
# 0.1791546742037785
# 0.8335988360834876
# 4.325815328687067
# 0.04102561817857608
# 0.08605987109214856
# 0.21847444414320213
# 2.1683039802245108
# 2.5158425151625887
# 0.2598281441936427
# 0.12138599128591954
# 1.1275197024597026
# 0.31196864319848766
# 0.29120231617893355
# 3.4472515649282633
# 1.1334082038922986
# 0.32207847065391343
# 0.17967248522491552
# 1.1043706355140352
# 0.9217731262667838
# 0.4885228482036977
# 1.2212470587690298
# 4.973933594163588
# 1.7938595970361895
# 1.049337260659806
# 1.693333552534169
# 0.602899058433685
# 0.08801193332673064
# 0.41208792009378886
# 0.3234088270849974
# 2.507918677716593
# 0.25708607682686374
# 0.22397897665737143
# 2.0831295920229405
# 0.28201804325341934
# 0.3259228041321121
# 1.4143904453142113
# 0.837058332391554
# 0.5812977084891754
# 0.26104502708999816
# 0.3004233875326016
# 0.4671929388923017
# 0.10262661825105235
# 1.2876895378445554
# 0.10216122749011207
# 0.20226394441226297
# 1.578777955936672
# 0.6279917426036503
# 0.1787808025070904
# 0.6198771581972704
# 0.4388270010358651
# 0.0623515824260866
# 1.0606332413985942
# 1.2278444592750841
# 0.39669896919671455
# 1.1379767080332053
# 0.028799235632715383
# 0.22815619728611605
# 1.9581542239350465
# 1.2093709462693192
# 0.10807232784572847
# 1.8898575924671785
# 1.2811445707270197
# 0.0077367489592831875
# 0.266479433640776
# 0.41853092785372364
# 0.025385376700874554
# 1.6345138178634735
# 4.701213806552137
# 0.8585470320234406
# 1.9953201039761324
# 0.7097070031093767
# 0.33145163901668717
# 0.1019058468560894
# 1.5887490180560433
# 0.31314311124030497
# 3.382333125475207
# 0.3840160761439324
# 0.2785428869429136
# 1.8445932692172868
# 0.5161174725515233
# 0.5834501700134497
# 7.275638334509166
# 0.022345061520564556
# 0.19461661195660157
# 1.0830508022875176
# 2.8085817310244163
# 0.06529931589722977
# 1.0764382764378082
# 0.11707606638230336
# 0.9904757870923577
# 0.6329506685329999
# 0.46264647296928246
# 0.034312092347506463
# 0.005718257138992981
# 0.09262099150420997
# 0.016847711839469096
# 0.2695711715215902
# 0.12484724623271863
# 0.8413922304720511
# 0.3487486501963373
# 0.5859260474143985
# 0.1766217305004554
# 4.276546858297407
# 4.710520072527527
# 1.9519356329825213
# 0.14080144765155003
# 0.6596319685388036
# 0.13108348422346125
# 0.2277548456876482
# 0.9334577262816671
# 0.44274351450816674
# 0.34782893217347793
# 0.7784311116840315
# 0.6360291398523724
# 0.8128810456948999
# 0.2777899553652064
# 0.6626278196935697
# 0.17536259379540095
# 0.36990937186959394
# 0.36248630402965465
# 0.36950403745683624
# 0.09736820160068604
# 0.761804593908617
# 1.0396602816213436
# 1.9669069545142335
# 0.9649214332336211
# 0.33322680219490036
# 2.9003616344844954
# 1.0080622255520801
# 2.698451276847495
# 1.7307930786181838
# 1.0920404547783644
# 1.3075853062439198
# 2.456631601986573
# 0.8089063104248246
# 1.0188288610317267
# 1.892941109321606
# 1.3124938798470818
# 3.7168175943109594
# 0.615669776288782
# 0.28787395326175347
# 0.5404924682728562
# 0.20952372085656978
# 1.3955952502184286
# 1.1639141784583713
# 0.23174028993717208
# 0.5854492565019592
# 0.15639634808595632
# 1.1009242854149035
# 0.0026538276733332014
# 1.1094785004389196
# 1.535207508334647
# 0.15803364929932884
# 0.20225615076832648
# 0.3820418058338592
# 0.4958221833499746
# 4.316544497069087
# 1.2066586029674597
# 0.9383744143737877
# 0.17741167383959636
# 0.10287302751585925
# 0.09500803623937842
# 0.04457779255826432
# 1.6729483449780425
# 0.6620969508390332
# 6.066772375496778
# 1.6831745948108794
# 0.11525829863825894
# 0.24979824008903098
# 0.11787436138614094
# 0.36833533007083386
# 0.5907508306375603
# 1.368376026383306
# 0.47241347292381813
# 0.2081578193366391
# 0.03644277289467124
# 0.7780289254799923
# 1.9792739211846155
# 0.3638459014780603
# 0.12564931727517525
# 0.06100215145683922
# 1.5064257985970406
# 2.695969917218287
# 1.658002069633427
# 4.305364908671658
# 0.284731696056178
# 0.9672746212549687
# 2.297911740694538
# 0.5838110045469508
# 0.05587650803087914
# 0.22624644107239916
# 0.09358662431909831
# 0.3376492064949158
# 3.602182957380098
# 0.7750889917814153
# 0.7539796383043147
# 1.703394358431376
# 0.07796512296876565
# 2.9501237277433345
# 0.3047075255886467
# 0.8042510846638123
# 2.636106575749615
# 0.2058689117586225
# 0.1843662816227379
# 1.7281311728123043
# 1.3958605427224757
# 2.2935246165858993
# 1.7214716086065254
# 1.5362348489060902
# 0.02181376062529829
# 0.18093277297312454
# 1.426482600088647
# 0.4674938714013801
# 0.5333975005116789
# 0.010908430503779671
# 0.017500899455103885
# 0.003824392433142723
# 0.006131797196640384
# 0.004207184516553116
# 0.013725450724376595
# 0.0018712254977706305
# 0.013119312572941657
# 0.5376811655195513
# 0.7526443637554899
# 2.543890559361367
# 1.2665073328564818
# 0.579398022767252
# 0.7992716866528615
# 1.6659706424543546
# 0.39020398945461693
# 2.789388740303748
# 0.018301336724193765
# 0.008290010727278817
# 0.24133351016996082
# 1.6204678541076751
# 0.5099874100418539
# 1.0782823802393093
# 0.0071765378497460975
# 0.024964582407621998
# 0.07631915768303577
# 2.0956997326586904
# 0.8878520732785904
# 0.7109972106953655
# 2.0198092131860714
# 2.5941807747672643
# 0.24850468051229885
# 0.22770376209393842
# 1.891614855225022
# 0.5767100161443081
# 0.16986852855688947
# 0.10157162046672427
# 1.5266596676998254
# 0.7447424924801843
# 1.7319728002574053
# 0.3012583565272079
# 0.4158326512460611
# 0.7380803375418603
# 0.6227312206963225
# 0.021183674706937623
# 1.9507394495860981
# 3.0602242833375715
# 1.58669336960637
# 0.14349473858871953
# 0.15879289796515608
# 0.5854370803896183
# 0.08631778341479535
# 0.8910027076807671
# 0.4390443951922147
# 1.753537758394338
# 0.5156556992049113
# 1.9928273879628293
# 0.4677955207878377
# 2.388096232708039
# 0.5788638393521864
# 0.017659910147330447
# 0.020239974727643315
# 0.6394675339235999
# 0.8479008959285826
# 0.043104756409475094
# 0.20288488358831513
# 0.07483296734806702
# 0.5958084416496647
# 1.7055820213224768
# 0.10795425941983293
# 0.7449367155190527
# 0.12389928320085805
# 0.36436440290423006
# 4.737870299704652
# 0.1281308922474071
# 0.28301411718694186
# 1.9323096917823308
# 1.5409502644583815
# 1.0588763189971815
# 8.92867966804514e-05
# 0.6165707012172479
# 0.2166315163219879
# 3.078816928749864
# 0.6443995863627268
# 0.7298729286488027
# 0.22663397956819625
# 1.2606028711634787
# 4.266085491033873
# 0.09570549953483616
# 3.3625953232519734
# 0.2240363744011956
# 0.1469042253465623
# 0.41785050715186456
# 1.9443786846163467
# 0.24564293256501468
# 0.7583421787441332
# 0.7950685612436165
# 1.4165130839562117
# 0.09512436017372611
# 0.6379164771028158
# 1.760973551736184
# 0.03141068445711457
# 1.414956103098038
# 1.860439831075611
# 1.6187013001606134
# 1.8330852205525714
# 1.7248675968978393
# 0.0645300727515931
# 0.024482875122794238
# 0.06798783315768663
# 0.5209462071992054
# 3.537279891953946
# 0.9384111142261212
# 0.273486120250516
# 0.3471362686285515
# 6.161518545328104
# 1.6889456054560523
# 0.03124619919325594
# 0.22530165453437426
# 0.1866398387556512
# 0.3168950256578781
# 3.518940882538706
# 0.2610820182166068
# 0.23496182797840398
# 3.49921524876659
# 0.7039384080386172
# 0.07534598548054477
# 0.046988795434229715
# 0.20177005546485025
# 0.4079782714433694
# 0.8404030414243668
# 0.28500441288825545
# 0.003864379240381015
# 0.16552652322842923
# 0.047945213574511945
# 0.05217639704240794
# 0.09219774375347894
# 0.9509448602280046
# 0.423027177115757
# 0.7886105672026716
# 1.1534159560990271
# 0.027188038002135026
# 0.09322587515873586
# 0.29321860063449634
# 0.03638807551156802
# 0.7277966232732751
# 0.14103780066322127
# 0.09960473388273505
# 1.0390376833169517
# 0.9398442105962914
# 1.302668181105822
# 0.46973019506245994
# 0.025903508903223467
# 0.0017128772101109371
# 0.060117823900980104
# 0.027525488817435537
# 0.0842502379429562
# 0.07381423502963344
# 0.07220538690864478
# 0.005380195583491096
# 0.010282915296289321
# 1.8681757072417158
# 0.36572483388670785
# 0.23234505087695942
# 0.008773685402326353
# 0.021077219095607395
# 0.01654057497019313
# 0.005894780070298185
# 0.08419458420774832
# 0.0808280403067091
# 0.003644677212498429
# 0.08695310071357192
# 0.04162237492227374
# 0.016031283113711832
# 2.8460659776319575
# 0.2184253466411557
# 2.4333818326010412
# 0.0706166314699714
# 0.47274160352543965
# 0.07237050625260934
# 2.6204544553567737
# 0.19672806042470176
# 0.4556192390824995
# 0.856144357020662
# 0.04380437224309145
# 0.026682046261475138
# 1.6420707471773401
# 1.224730480192173
# 0.04494288106408918
# 0.11232679025467711
# 1.9025615725421308
# 0.2663706740284566
# 0.14763629195082348
# 0.2072889277720513
# 0.002942204804858842
# 0.12726730123705074
# 0.033850719439195674
# 0.21395292925891143
# 1.430062672083192
# 0.4438875121398072
# 0.6602097154717027
# 0.40863220125466143
# 1.7138857485721266
# 1.566312455329828
# 2.4814009458772865
# 0.09856655470283365
# 0.05997145402394851
# 1.296054903036338
# 0.5532456829077553
# 0.0327183770770502
# 0.45936831758795327
# 0.7948828481677741
# 0.14866760453835365
# 0.006186474343203267
# 1.0599613183412337
# 0.41950746971555297
# 0.5341345088385604
# 0.07960914432016648
# 0.14092522090062684
# 2.0451109428074177
# 0.006884876227861712
# 0.14781131186267923
# 2.9181838615408706
# 0.065458841797516
# 0.01173096147381111
# 0.05540532074729901
# 0.12119834242879575
# 1.2100052493986322
# 1.1190559036317158
# 2.244945168956216
# 0.11337008316443452
# 1.527396881588219
# 0.018505572894456812
# 0.008079014182789076
# 1.327630391181983
# 1.7606678504436961
# 0.26453321822983633
# 0.020261905444926474
# 0.04704300814282083
# 0.005908783170310176
# 0.24645586885035325
# 0.2973771598874651
# 0.21078660868054763
# 1.0730463427836923
# 0.5236436958286974
# 0.5827860234413926
# 1.3608862245726785
# 0.45257710700342696
# 1.176051510660633
# 0.030649522157555092
# 0.19591856926150836
# 0.6803884109675531
# 1.5388364897947169
# 2.181326064972917
# 0.20800128463333145
# 0.27224656654000384
# 2.0849288743309216
# 0.02857351676223839
# 0.14938970717484093
# 0.06306968279379915
# 1.8098550988655802
# 2.6898739930908877
# 0.2981157516833696
# 0.7400337429415691
# 0.2515394117082959
# 0.11394715771040152
# 2.4818253628680047
# 0.44051570650775895
# 2.6236217588659843
# 0.2627412492381912
# 1.059100750209868
# 0.4719592614585274
# 0.4188808778750233
# 1.226585980892088
# 0.3509667736489061
# 1.3783786713845254
# 0.6804625713910559
# 4.370352840588568
# 1.1495016950324355
# 0.08957509837086888
# 1.1548175138683623
# 0.14462849779939213
# 2.42076359829838
# 0.013420849511927563
# 0.1424174779609674
# 0.01508529146324033
# 0.7782568630230627
# 3.7382454520162605
# 0.001006482615201675
# 1.0879442546767788
# 0.3469384923791113
# 0.07236068476173643
# 5.268409947526631
# 0.3215583503619423
# 1.0359283665833123

# %%
#.................................................................................
#... for the averaged morphological vector combo, estimate the new form of the target word
#.................................................................................

def morphology(word_seq):
    global word_embeddings, proj_embeddings, uniqueWords, wordcodes
    embeddings = word_embeddings
    vectors = [word_seq[0], # suffix averaged
    embeddings[wordcodes[word_seq[1]]]]
    vector_math = vectors[0]+vectors[1]
    #... find whichever vector is closest to vector_math
    #... (TASK) Use the same approach you used in function prediction() to construct a list
    #... of top 10 most similar words to vector_math. Return this list.

# %%
#.................................................................................
#... for the triplet (A,B,C) find D such that the analogy A is to B as C is to D is most likely
#.................................................................................

def analogy(word_seq):
    global word_embeddings, proj_embeddings, uniqueWords, wordcodes
    embeddings = word_embeddings
    vectors = [embeddings[wordcodes[word_seq[0]]],
    embeddings[wordcodes[word_seq[1]]],
    embeddings[wordcodes[word_seq[2]]]]
    vector_math = -vectors[0] + vectors[1] - vectors[2] # + vectors[3] = 0
    #... find whichever vector is closest to vector_math
    #... (TASK) Use the same approach you used in function prediction() to construct a list
    #... of top 10 most similar words to vector_math. Return this list.

# %%
#.................................................................................
#... find top 10 most similar words to a target word
#.................................................................................

from scipy import spatial
def get_neighbors(target_word):
    global word_embeddings, uniqueWords, wordcodes
    targets = [target_word]
    outputs = []
    tempDict = {}
    resultDict = {}
    #... (TASK) search through all uniqueWords and for each token, compute its similarity to target_word.
    targetIndex = wordcodes[target_word]
    for i in range(len(uniqueWords)):
        if i != targetIndex:
            tempDict[uniqueWords[i]] = 1 - spatial.distance.cosine(word_embeddings[i], word_embeddings[targetIndex])
    
        
    #... you will compute this using the absolute cosine similarity of the word_embeddings for the word pairs.
    #... Note that the cosine() function from scipy.spatial.distance computes a DISTANCE so you need to convert that to a similarity.
    #... return a list of top 10 most similar words in the form of dicts,
    #... each dict having format: {"word":<token_name>, "score":<cosine_similarity>}
    outputs = sorted(tempDict, key = tempDict.get, reverse = True)
    for word in outputs[:10]:
        resultDict[word] = tempDict[word]
    
    
    
    return resultDict

# %%
def count_similiarity(word1, word2):
    global word_embeddings, wordcodes
    word1_index = wordcodes[word1]
    word2_index = wordcodes[word2]
    result = 1 - spatial.distance.cosine(word_embeddings[word1_index], word_embeddings[word2_index])
    return result

# %%
import csv

with open('intrinsic-test.tsv','r') as tsvfile:
    with open('result.csv','w') as re:
        writer = csv.writer(re, delimiter=',')
        writer.writerow(['id', 'sim'])
        test_data  = csv.reader(tsvfile, delimiter='\t', )
        next(test_data, None)
        for row in test_data:
            try:
                result = count_similiarity(row[1], row[2])
                index = row[0]
                writer.writerow([index, result])
            except:
                writer.writerow([row[0],])

# %%
import pandas as pd

# %%
result = pd.read_csv('result.csv')

# %%
if __name__ == '__main__':
    if len(sys.argv)==2:
        filename = sys.argv[1]
        #... load in the file, tokenize it and assign each token an index.
        #... the full sequence of characters is encoded in terms of their one-hot positions

        fullsequence= loadData(filename)
        print ("Full sequence loaded...")
        #print(uniqueWords)
        #print (len(uniqueWords))



        #... now generate the negative sampling table
        print ("Total unique words: ", len(uniqueWords))
        print("Preparing negative sampling table")
        samplingTable = negativeSampleTable(fullsequence, uniqueWords, wordcounts)


        #... we've got the word indices and the sampling table. Begin the training.
        #... NOTE: If you have already trained a model earlier, preload the results (set preload=True) (This would save you a lot of unnecessary time)
        #... If you just want to load an earlier model and NOT perform further training, comment out the train_vectors() line
        #... ... and uncomment the load_model() line

        train_vectors(preload=True)
        [word_embeddings, proj_embeddings] = load_model()








        #... we've got the trained weight matrices. Now we can do some predictions
        targets = ["good", "bad", "scary", "funny"]
        for targ in targets:
            print("Target: ", targ)
            bestpreds= (prediction(targ))
            for pred in bestpreds:
                print (pred["word"],":",pred["score"])
            print ("\n")



        #... try an analogy task. The array should have three entries, A,B,C of the format: A is to B as C is to ?
        print (analogy(["son", "daughter", "man"]))
        print (analogy(["thousand", "thousands", "hundred"]))
        print (analogy(["amusing", "fun", "scary"]))
        print (analogy(["terrible", "bad", "amazing"]))



        #... try morphological task. Input is averages of vector combinations that use some morphological change.
        #... see how well it predicts the expected target word when using word_embeddings vs proj_embeddings in
        #... the morphology() function.

        s_suffix = [word_embeddings[wordcodes["stars"]] - word_embeddings[wordcodes["star"]]]
        others = [["types", "type"],
                  ["ships", "ship"],
                  ["values", "value"],
                  ["walls", "wall"],
                  ["spoilers", "spoiler"]]
        for rec in others:
            s_suffix.append(word_embeddings[wordcodes[rec[0]]] - word_embeddings[wordcodes[rec[1]]])
        s_suffix = np.mean(s_suffix, axis=0)
        print (morphology([s_suffix, "techniques"]))
        print (morphology([s_suffix, "sons"]))
        print (morphology([s_suffix, "secrets"]))






    else:
        print ("Please provide a valid input filename")
        sys.exit()
